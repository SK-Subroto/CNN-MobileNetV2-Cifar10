# %% [markdown]
# <a href="https://colab.research.google.com/github/SK-Subroto/CNN-MobileNetV2-Cifar10/blob/master/cifer10Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.utils.multiclass import unique_labels

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
# print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
#Import standard libraries

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
''' to learn more about itertools visit
    https://medium.com/@jasonrigden/a-guide-to-python-itertools-82e5a306cdf8'''
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Import keras functions

from keras import Sequential

'''Since we are using transfer learning let's import the model that we want to implement.Let's use VGG 19(19 layers) and Resnet-50 (50 layers of residual units). 
Residual units allow us to add more layers onto the model without a degradation in accuracy.
Let's try and compare the accuracy of the 2 models and see if the addtional layers do make a significant difference. '''

from keras.applications import VGG19,ResNet50

'Import the datagenerator to augment images'
from keras.preprocessing.image import ImageDataGenerator

'''Import the optimizers and leanring rate annealer (which will reduce the learning rate once a particular metric we choose(in this case validation error) 
does not reduce after a user defined number of epochs)'''
from keras.optimizers import SGD,Adam
from keras.callbacks import ReduceLROnPlateau

'Lastly import the final layers that will be added on top of the base model'
from keras.layers import Flatten,Dense,BatchNormalization,Activation,Dropout

'Import to_categorical from the keras utils package to one hot encode the labels'
from keras.utils import to_categorical

# %%
#Import dataset
from keras.datasets import cifar10

# %%
#Divide the data in Train, Validation and Test Datasets
'I had to turn the Internet setting to on to download load the dataset'
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=.3)

# %%
#One hot encode the labels.Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10

y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

# %%
# Lets print the dimensions one more time to see if things changed the way we expected

print((x_train.shape,y_train.shape))
print((x_val.shape,y_val.shape))
print((x_test.shape,y_test.shape))
# Out:
# ((35000, 32, 32, 3), (35000, 10))
# ((15000, 32, 32, 3), (15000, 10))
# ((10000, 32, 32, 3), (10000, 10))

# %%
# the parameters.We have to instantiate for the Train,Validation and Test datasets
train_generator = ImageDataGenerator(
                                    rotation_range=2, 
                                    horizontal_flip=True,
                                    zoom_range=.1 )

val_generator = ImageDataGenerator(
                                    rotation_range=2, 
                                    horizontal_flip=True,
                                    zoom_range=.1)

test_generator = ImageDataGenerator(
                                    rotation_range=2, 
                                    horizontal_flip= True,
                                    zoom_range=.1)

# %%
#Fit the augmentation method to the data

train_generator.fit(x_train)
val_generator.fit(x_val)
test_generator.fit(x_test)

# %%
'''Learning Rate Annealer: The learning rate can be modified after a set number of epochs or after a certain condition is met. We will use the latter and change the learning rate if 
the validation error does not reduce after a set number of epochs. To do this we will use the patience parameter.'''

lrr= ReduceLROnPlateau(
                       monitor='val_acc', #Metric to be measured
                       factor=.01, #Factor by which learning rate will be reduced
                       patience=3,  #No. of epochs after which if there is no improvement in the val_acc, the learning rate is reduced
                       min_lr=1e-5) #The minimum learning rate

# %%
#Build the model

'The first base model used is VGG19. The pretrained weights from the imagenet challenge are used'
base_model_1 = VGG19(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=y_train.shape[1])

'For the 2nd base model we will use Resnet 50 and compare the performance against the previous one.The hypothesis is that Resnet 50 should perform better because of its deeper architecture'
base_model_2 = ResNet50(include_top=False,weights='imagenet',input_shape=(32,32,3),classes=y_train.shape[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
#Lets add the final layers to these base models where the actual classification is done in the dense layers

model_1= Sequential()
model_1.add(base_model_1) #Adds the base model (in this case vgg19 to model_1)
model_1.add(Flatten()) #Since the output before the flatten layer is a matrix we have to use this function to get a vector of the form nX1 to feed it into the fully connected layers

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Add the Dense layers along with activation and batch normalization
model_1.add(Dense(1024,activation=('relu'),input_dim=512))
model_1.add(Dense(512,activation=('relu'))) 
model_1.add(Dense(256,activation=('relu'))) 
#model_1.add(Dropout(.3))#Adding a dropout layer that will randomly drop 30% of the weights
model_1.add(Dense(128,activation=('relu')))
#model_1.add(Dropout(.2))
model_1.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %%
#Check final model summary
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 1, 1, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 21,240,010
# Trainable params: 21,240,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size= 100
epochs=50

# %%
learn_rate=.001

sgd=SGD(lr=learn_rate,momentum=.9,nesterov=False)
adam=Adam(lr=learn_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# %%
#Compile the model
#During model compiling the 3 main things we specify are loss function,optimizer and the metrics that need to be evaluated during the test and train processes.
#Lets start by using the SGD optimizer
#We will specify the loss as categoricl crossentropy since the labels are 1 hot encoded. IF we had integer labels,we'd have to use sparse categorical crossentropy as loss function.
model_1.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model_1.fit_generator(train_generator.flow(x_train,y_train,batch_size=batch_size),
                      epochs=epochs,
                      steps_per_epoch=x_train.shape[0]//batch_size,
                      validation_data=val_generator.flow(x_val,y_val,batch_size=batch_size),validation_steps=250,
                      callbacks=[lrr],verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-20-51241dcc88e5>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
#   2/350 [..............................] - ETA: 9s - loss: 5.4860 - accuracy: 0.1200WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0218s vs `on_train_batch_end` time: 0.0419s). Check your callbacks.
# 350/350 [==============================] - ETA: 0s - loss: 2.0311 - accuracy: 0.2143WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 250 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 350/350 [==============================] - 27s 77ms/step - loss: 2.0311 - accuracy: 0.2143 - val_loss: 1.6031 - val_accuracy: 0.4006
# Epoch 2/50
# 350/350 [==============================] - ETA: 0s - loss: 1.2751 - accuracy: 0.5331WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 1.2751 - accuracy: 0.5331
# Epoch 3/50
# 350/350 [==============================] - ETA: 0s - loss: 0.8864 - accuracy: 0.6926WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.8864 - accuracy: 0.6926
# Epoch 4/50
# 350/350 [==============================] - ETA: 0s - loss: 0.7219 - accuracy: 0.7526WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.7219 - accuracy: 0.7526
# Epoch 5/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7863WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.6223 - accuracy: 0.7863
# Epoch 6/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5393 - accuracy: 0.8179WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.5393 - accuracy: 0.8179
# Epoch 7/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.8357WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.4828 - accuracy: 0.8357
# Epoch 8/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4394 - accuracy: 0.8488WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.4394 - accuracy: 0.8488
# Epoch 9/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4021 - accuracy: 0.8627WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.4021 - accuracy: 0.8627
# Epoch 10/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3629 - accuracy: 0.8760WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.3629 - accuracy: 0.8760
# Epoch 11/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8912WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.3181 - accuracy: 0.8912
# Epoch 12/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2993 - accuracy: 0.8962WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.2993 - accuracy: 0.8962
# Epoch 13/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9074WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.2632 - accuracy: 0.9074
# Epoch 14/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9160WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.2422 - accuracy: 0.9160
# Epoch 15/50
# 350/350 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9242WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.2171 - accuracy: 0.9242
# Epoch 16/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9311WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.1970 - accuracy: 0.9311
# Epoch 17/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9392WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1746 - accuracy: 0.9392
# Epoch 18/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9432WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1655 - accuracy: 0.9432
# Epoch 19/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9467WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1515 - accuracy: 0.9467
# Epoch 20/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9513WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1407 - accuracy: 0.9513
# Epoch 21/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9563WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.1255 - accuracy: 0.9563
# Epoch 22/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9608WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.1125 - accuracy: 0.9608
# Epoch 23/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9659WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.1016 - accuracy: 0.9659
# Epoch 24/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9690WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0887 - accuracy: 0.9690
# Epoch 25/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9685WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0929 - accuracy: 0.9685
# Epoch 26/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9730WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0800 - accuracy: 0.9730
# Epoch 27/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9742WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0765 - accuracy: 0.9742
# Epoch 28/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9742WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0752 - accuracy: 0.9742
# Epoch 29/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9765WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0693 - accuracy: 0.9765
# Epoch 30/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9808WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0575 - accuracy: 0.9808
# Epoch 31/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9779WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0649 - accuracy: 0.9779
# Epoch 32/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9832WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0484 - accuracy: 0.9832
# Epoch 33/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9819WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0541 - accuracy: 0.9819
# Epoch 34/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9818WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0533 - accuracy: 0.9818
# Epoch 35/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9858WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0412 - accuracy: 0.9858
# Epoch 36/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9841WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0456 - accuracy: 0.9841
# Epoch 37/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9854WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0418 - accuracy: 0.9854
# Epoch 38/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9874WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0365 - accuracy: 0.9874
# Epoch 39/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9874WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0370 - accuracy: 0.9874
# Epoch 40/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9875WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0362 - accuracy: 0.9875
# Epoch 41/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9880WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0373 - accuracy: 0.9880
# Epoch 42/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9878WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0366 - accuracy: 0.9878
# Epoch 43/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9892WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0312 - accuracy: 0.9892
# Epoch 44/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9907WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 61ms/step - loss: 0.0288 - accuracy: 0.9907
# Epoch 45/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9928WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0222 - accuracy: 0.9928
# Epoch 46/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9921WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0254 - accuracy: 0.9921
# Epoch 47/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9905WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0283 - accuracy: 0.9905
# Epoch 48/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9931WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0202 - accuracy: 0.9931
# Epoch 49/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9914WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0246 - accuracy: 0.9914
# Epoch 50/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9918WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 21s 60ms/step - loss: 0.0245 - accuracy: 0.9918

# %%
#Plot the training and valiation loss
'''The output of model.fit is a model.History object which is a record of metrics at each epoch. This can be used to graph the training and validation accuracy
to see where they plateaued off and if overfitting can subsequently be avoided'''

f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

#Assign the first subplot to graph training loss and validation loss
ax[0].plot(model_1.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(model_1.history.history['val_loss'],color='r',label='Validation Loss')

#Next lets plot the training accuracy and validation accuracy
# ax[1].plot(model_1.history.history['acc'],color='b',label='Training  Accuracy')
# ax[1].plot(model_1.history.history['val_acc'],color='r',label='Validation Accuracy')

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#     print(cm)

    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

# %%
y_pred=model_1.predict_classes(x_test)
y_true=np.argmax(y_test,axis=1)

#Compute the confusion matrix
confusion_mtx=confusion_matrix(y_true,y_pred)
# Out:
# WARNING:tensorflow:From <ipython-input-23-c294763353bf>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
class_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=class_names,
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
# plt.show()
# Out:
# Normalized confusion matrix

# %%
#Since we have already defined Resnet50 as base_model_2, let us build the sequential model.

model_2=Sequential()
#Add the Dense layers along with activation and batch normalization
model_2.add(base_model_2)
model_2.add(Flatten())


#Add the Dense layers along with activation and batch normalization
model_2.add(Dense(4000,activation=('relu'),input_dim=512))
model_2.add(Dense(2000,activation=('relu'))) 
model_2.add(Dropout(.4))
model_2.add(Dense(1000,activation=('relu'))) 
model_2.add(Dropout(.3))#Adding a dropout layer that will randomly drop 30% of the weights
model_2.add(Dense(500,activation=('relu')))
model_2.add(Dropout(.2))
model_2.add(Dense(10,activation=('softmax'))) #This is the classification layer

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4000)              8196000
# _________________________________________________________________
# dense_6 (Dense)              (None, 2000)              8002000
# _________________________________________________________________
# dropout (Dropout)            (None, 2000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1000)              2001000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 42,292,222
# Trainable params: 42,239,102
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
#Compile the model 

model_2.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model_2.fit_generator(train_generator.flow(x_train,y_train,batch_size=batch_size),
                     epochs=50,steps_per_epoch=x_train.shape[0]//batch_size,
                     validation_data=val_generator.flow(x_val,y_val,batch_size=batch_size),validation_steps=250,
                      callbacks=[lrr],verbose=1)
# Out:
# Epoch 1/50
# 350/350 [==============================] - ETA: 0s - loss: 1.6815 - accuracy: 0.4161WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 250 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 350/350 [==============================] - 30s 85ms/step - loss: 1.6815 - accuracy: 0.4161 - val_loss: 3.0407 - val_accuracy: 0.3613
# Epoch 2/50
# 350/350 [==============================] - ETA: 0s - loss: 1.1081 - accuracy: 0.6398WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 1.1081 - accuracy: 0.6398
# Epoch 3/50
# 350/350 [==============================] - ETA: 0s - loss: 0.9257 - accuracy: 0.7087WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.9257 - accuracy: 0.7087
# Epoch 4/50
# 350/350 [==============================] - ETA: 0s - loss: 0.9778 - accuracy: 0.6888WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.9778 - accuracy: 0.6888
# Epoch 5/50
# 350/350 [==============================] - ETA: 0s - loss: 0.9527 - accuracy: 0.6952WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 64ms/step - loss: 0.9527 - accuracy: 0.6952
# Epoch 6/50
# 350/350 [==============================] - ETA: 0s - loss: 0.7760 - accuracy: 0.7540WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.7760 - accuracy: 0.7540
# Epoch 7/50
# 350/350 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.7749WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.7149 - accuracy: 0.7749
# Epoch 8/50
# 350/350 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.7684WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.7273 - accuracy: 0.7684
# Epoch 9/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7930WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 64ms/step - loss: 0.6513 - accuracy: 0.7930
# Epoch 10/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.8031WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.6385 - accuracy: 0.8031
# Epoch 11/50
# 350/350 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.7717WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.7236 - accuracy: 0.7717
# Epoch 12/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.8015WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.6270 - accuracy: 0.8015
# Epoch 13/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.8313WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.5338 - accuracy: 0.8313
# Epoch 14/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.8327WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.5342 - accuracy: 0.8327
# Epoch 15/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5561 - accuracy: 0.8255WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 64ms/step - loss: 0.5561 - accuracy: 0.8255
# Epoch 16/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.8479WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.4865 - accuracy: 0.8479
# Epoch 17/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6459 - accuracy: 0.8009WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.6459 - accuracy: 0.8009
# Epoch 18/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.7861WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6837 - accuracy: 0.7861
# Epoch 19/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4725 - accuracy: 0.8515WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.4725 - accuracy: 0.8515
# Epoch 20/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4519 - accuracy: 0.8634WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.4519 - accuracy: 0.8634
# Epoch 21/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.8029WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6485 - accuracy: 0.8029
# Epoch 22/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6564 - accuracy: 0.7956WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6564 - accuracy: 0.7956
# Epoch 23/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.8406WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.5137 - accuracy: 0.8406
# Epoch 24/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4153 - accuracy: 0.8703WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.4153 - accuracy: 0.8703
# Epoch 25/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8841WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.3673 - accuracy: 0.8841
# Epoch 26/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3743 - accuracy: 0.8848WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.3743 - accuracy: 0.8848
# Epoch 27/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.7955WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6666 - accuracy: 0.7955
# Epoch 28/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5923 - accuracy: 0.8191WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.5923 - accuracy: 0.8191
# Epoch 29/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.8318WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 65ms/step - loss: 0.5443 - accuracy: 0.8318
# Epoch 30/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.8527WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.4663 - accuracy: 0.8527
# Epoch 31/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6324 - accuracy: 0.8117WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6324 - accuracy: 0.8117
# Epoch 32/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.8007WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.6326 - accuracy: 0.8007
# Epoch 33/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5509 - accuracy: 0.8254WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.5509 - accuracy: 0.8254
# Epoch 34/50
# 350/350 [==============================] - ETA: 0s - loss: 0.5820 - accuracy: 0.8170WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 22s 64ms/step - loss: 0.5820 - accuracy: 0.8170
# Epoch 35/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.8484WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 23s 66ms/step - loss: 0.4908 - accuracy: 0.8484
# Epoch 36/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4967 - accuracy: 0.8478WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 24s 68ms/step - loss: 0.4967 - accuracy: 0.8478
# Epoch 37/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.8807WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.3898 - accuracy: 0.8807
# Epoch 38/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8549WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4625 - accuracy: 0.8549
# Epoch 39/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8909WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.3514 - accuracy: 0.8909
# Epoch 40/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3520 - accuracy: 0.8898WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.3520 - accuracy: 0.8898
# Epoch 41/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.8607WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4418 - accuracy: 0.8607
# Epoch 42/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8549WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 75ms/step - loss: 0.4726 - accuracy: 0.8549
# Epoch 43/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4580 - accuracy: 0.8581WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4580 - accuracy: 0.8581
# Epoch 44/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8665WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4369 - accuracy: 0.8665
# Epoch 45/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.8095WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.6199 - accuracy: 0.8095
# Epoch 46/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8473WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4939 - accuracy: 0.8473
# Epoch 47/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8474WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.4826 - accuracy: 0.8474
# Epoch 48/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4597 - accuracy: 0.8592WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 75ms/step - loss: 0.4597 - accuracy: 0.8592
# Epoch 49/50
# 350/350 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.8895WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 74ms/step - loss: 0.3494 - accuracy: 0.8895
# Epoch 50/50
# 350/350 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.8520WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,lr
# 350/350 [==============================] - 26s 75ms/step - loss: 0.4915 - accuracy: 0.8520

# %%
f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

#Assign the first subplot to graph training loss and validation loss
ax[0].plot(model_2.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(model_2.history.history['val_loss'],color='r',label='Validation Loss')

#Next lets plot the training accuracy and validation accuracy
# ax[1].plot(model_2.history.history['acc'],color='b',label='Training  Accuracy')
# ax[1].plot(model_2.history.history['val_acc'],color='r',label='Validation Accuracy')

# %%
y_pred_resnet=model_2.predict_classes(x_test)
y_true=np.argmax(y_test,axis=1)

#Compute the confusion matrix
confusion_mtx=confusion_matrix(y_true,y_pred_resnet)

# %%
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred_resnet, classes=class_names,
                      title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(y_true, y_pred_resnet, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
# plt.show()
# Out:
# Normalized confusion matrix
